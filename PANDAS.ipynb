# %%
#INSTALLING PANDAS LIBRARY

# !pip install pandas
import pandas
pandas.__version__
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# '1.3.5'

# %%
#INITIALIZATION

#Loading Data-Series
 
      #With Index
import pandas as pd
a = [7,9,4]
dataset = pd. Series(a)
print(dataset)
# Out:
# 0    7
# 1    9
# 2    4
# dtype: int64

# %%
      #Without Index
import pandas as pd
a = [7,9,4]
dataset = pd.Series(a, index = ['No.1', 'No.2', 'No.3' ])
print(dataset)
# Out:
# No.1    7
# No.2    9
# No.3    4
# dtype: int64

# %%
#Loading Data- DataFrame

import pandas as pd
data = {"Name" :["Fred", "Daniel", "Alfred"],"Color":["Green", "Blue", "Purple"]}
dataset = pd.DataFrame(data)
print(dataset)
# Out:
#      Name   Color
# 0    Fred   Green
# 1  Daniel    Blue
# 2  Alfred  Purple

# %%
# LOADING DATASET FROM FILE

 #Loading a CSV file

import pandas as pd
dataset1 = pd.read_csv("dataset.csv")
print(dataset1.head(5))  #head gives the top e.g 5 values and tail gives the bottom
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
#Loading an Excel File

import pandas as pd
dataset2 = pd.read_excel("dataset.xlsx")
print(dataset2.head(5))
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
#Loading a Text file

import pandas as pd
dataset3 = pd.read_csv("dataset.txt")
print(dataset3.head(5))
# Out:
#   #\tName\tType 1\tType 2\tHP\tAttack\tDefense\tSp. Atk\tSp. Def\tSpeed\tGeneration\tLegendary
# 0  1\tBulbasaur\tGrass\tPoison\t45\t49\t49\t65\t6...
# 1  2\tIvysaur\tGrass\tPoison\t60\t62\t63\t80\t80\...
# 2  3\tVenusaur\tGrass\tPoison\t80\t82\t83\t100\t1...
# 3  3\tVenusaurMega Venusaur\tGrass\tPoison\t80\t1...
# 4  4\tCharmander\tFire\t\t39\t52\t43\t60\t50\t65\...

# %%
#DATASET DETAILS

print(dataset1.shape) #No of Rows and Columns
print(dataset1.describe()) #Detailed infoabout Dataset
# Out:
# (800, 12)
#                 #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.000000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750   69.258750   79.001250   73.842500   72.820000   71.902500
# std    208.343798   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.000000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    184.750000   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    364.500000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    539.250000   80.000000  100.000000   90.000000   95.000000   90.000000
# max    721.000000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# ...

# %%
#DATASET SLICING

print(dataset1.columns) #To get only column title
print(dataset1["Name"]) #To get data from specific name of a column
print(dataset1[["Name", "Speed"]]) #To get data from multiple columns together
print(dataset1["Name"][0:10]) #To get data from specific number of columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')
# 0                  Bulbasaur
# 1                    Ivysaur
# 2                   Venusaur
# 3      VenusaurMega Venusaur
# 4                 Charmander
#                ...
# 795                  Diancie
# 796      DiancieMega Diancie
# 797      HoopaHoopa Confined
# 798       HoopaHoopa Unbound
# 799                Volcanion
# Name: Name, Length: 800, dtype: object
#                       Name  Speed
# 0                Bulbasaur     45
# 1                  Ivysaur     60
# 2                 Venusaur     80
# 3    VenusaurMega Venusaur     80
# 4               Charmander     65
# ..                     ...    ...
# 795                Diancie     50
# 796    DiancieMega Diancie    110
# 797    HoopaHoopa Confined     70
# 798     HoopaHoopa Unbound     80
# 799              Volcanion     70
#
# [800 rows x 2 columns]
# ...

# %%
print(dataset1.iloc[0]) #integer location- to acquire complete info about a certain index
print(dataset1.iloc[1:5]) #acquire complete info about range of index
print(dataset1.iloc[1,2]) #acquire specific cell data
# Out:
# #                     1
# Name          Bulbasaur
# Type 1            Grass
# Type 2           Poison
# HP                   45
# Attack               49
# Defense              49
# Sp. Atk              65
# Sp. Def              65
# Speed                45
# Generation            1
# Legendary         False
# Name: 0, dtype: object
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False
# Grass

# %%
#Iterrows

for index, row in dataset1.iterrows():
  print(index,row["Name"])
# Out:
# 0 Bulbasaur
# 1 Ivysaur
# 2 Venusaur
# 3 VenusaurMega Venusaur
# 4 Charmander
# 5 Charmeleon
# 6 Charizard
# 7 CharizardMega Charizard X
# 8 CharizardMega Charizard Y
# 9 Squirtle
# 10 Wartortle
# 11 Blastoise
# 12 BlastoiseMega Blastoise
# 13 Caterpie
# 14 Metapod
# 15 Butterfree
# 16 Weedle
# 17 Kakuna
# 18 Beedrill
# 19 BeedrillMega Beedrill
# 20 Pidgey
# 21 Pidgeotto
# 22 Pidgeot
# 23 PidgeotMega Pidgeot
# 24 Rattata
# 25 Raticate
# 26 Spearow
# 27 Fearow
# 28 Ekans
# 29 Arbok
# 30 Pikachu
# 31 Raichu
# 32 Sandshrew
# 33 Sandslash
# 34 Nidoran (Female)
# 35 Nidorina
# 36 Nidoqueen
# 37 Nidoran (Male)
# 38 Nidorino
# 39 Nidoking
# 40 Clefairy
# 41 Clefable
# 42 Vulpix
# 43 Ninetales
# 44 Jigglypuff
# 45 Wigglytuff
# 46 Zubat
# 47 Golbat
# 48 Oddish
# 49 Gloom
# 50 Vileplume
# 51 Paras
# 52 Parasect
# 53 Venonat
# 54 Venomoth
# 55 Diglett
# 56 Dugtrio
# 57 Meowth
# 58 Persian
# 59 Psyduck
# 60 Golduck
# 61 Mankey
# 62 Primeape
# 63 Growlithe
# 64 Arcanine
# 65 Poliwag
# ...

# %%
#Data Slicing with Filter

print(dataset1.loc[dataset1["Speed"]>90])
# Out:
#        #                       Name  Type 1  Type 2   HP  Attack  Defense  \
# 6      6                  Charizard    Fire  Flying   78      84       78
# 7      6  CharizardMega Charizard X    Fire  Dragon   78     130      111
# 8      6  CharizardMega Charizard Y    Fire  Flying   78     104       78
# 19    15      BeedrillMega Beedrill     Bug  Poison   65     150       40
# 22    18                    Pidgeot  Normal  Flying   83      80       75
# ..   ...                        ...     ...     ...  ...     ...      ...
# 791  715                    Noivern  Flying  Dragon   85      70       80
# 792  716                    Xerneas   Fairy     NaN  126     131       95
# 793  717                    Yveltal    Dark  Flying  126     131       95
# 794  718           Zygarde50% Forme  Dragon  Ground  108     100      121
# 796  719        DiancieMega Diancie    Rock   Fairy   50     160      110
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
print(dataset1.loc[dataset1["Type 2"] == "Poison"])
# Out:
#        #                   Name Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 0      1              Bulbasaur  Grass  Poison   45      49       49       65
# 1      2                Ivysaur  Grass  Poison   60      62       63       80
# 2      3               Venusaur  Grass  Poison   80      82       83      100
# 3      3  VenusaurMega Venusaur  Grass  Poison   80     100      123      122
# 16    13                 Weedle    Bug  Poison   40      35       30       20
# 17    14                 Kakuna    Bug  Poison   45      25       50       25
# 18    15               Beedrill    Bug  Poison   65      90       40       45
# 19    15  BeedrillMega Beedrill    Bug  Poison   65     150       40       15
# 48    43                 Oddish  Grass  Poison   45      50       55       75
# 49    44                  Gloom  Grass  Poison   60      65       70       85
# 50    45              Vileplume  Grass  Poison   75      80       85      110
# ...

# %%
#Slicing-Sorting Data

dataset1.sort_values(["HP"], ascending=False) #meaning descending order
dataset1.sort_values(["Speed"], ascending=True)
# Out:
#        #                   Name   Type 1  Type 2   HP  Attack  Defense  \
# 495  446               Munchlax   Normal     NaN  135      85       40
# 230  213                Shuckle      Bug    Rock   20      10      230
# 658  597              Ferroseed    Grass   Steel   44      50       91
# 486  438                 Bonsly     Rock     NaN   50      80       95
# 359  328               Trapinch   Ground     NaN   45     100       45
# ..   ...                    ...      ...     ...  ...     ...      ...
# 429  386     DeoxysAttack Forme  Psychic     NaN   50     180       20
# 71    65  AlakazamMega Alakazam  Psychic     NaN   55      50       65
# 428  386     DeoxysNormal Forme  Psychic     NaN   50     150       50
# 315  291                Ninjask      Bug  Flying   61      90       45
# 431  386      DeoxysSpeed Forme  Psychic     NaN   50      95       90
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 495       40       85      5           4      False
# ...

# %%
#EDITING

#Adding a column

dataset1["Power"] = dataset1["HP"] + dataset1["Attack"]
print(dataset1.head(5))
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  Power
# 0       65     45           1      False     94
# 1       80     60           1      False    122
# 2      100     80           1      False    162
# 3      120     80           1      False    180
# 4       50     65           1      False     91

# %%
# Remove a column

dataset1= dataset1.drop(columns=["Power"])
print(dataset1.head(5))
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
# SAVING DATASET

dataset1.to_csv("newDataset.csv")
dataset1.to_excel("newDataset.xlsx")
dataset1.to_csv("newDataset.txt")

# %%
# NaN VALUES IN DATASET

#Check 

dataset1.isna().any()
# Out:
# #             False
# Name          False
# Type 1        False
# Type 2        False
# HP            False
# Attack        False
# Defense       False
# Sp. Atk       False
# Sp. Def       False
# Speed         False
# Generation    False
# Legendary     False
# dtype: bool

# %%
# Acquring dataset without NaN value by removing entire column

dataset1 = dataset1[dataset1["Type 2"].notna()]

# %%
# Filling NaN with mean/median of that specific column

MeandatasetNotNan = dataset1["Speed"].fillna(dataset["Speed"].mean())
MeandatasetNotNan

#In the practice there was no NaN on Speed Column
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Speed'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
# MAPPING  CERTAIN VALUE TO ANOTHER

print(dataset1.tail(5))
Generation = set(dataset1["Generation"])
dataset1["Generation"] = dataset1["Generation"].map({1: "One", 2: "Two", 3: "Three", 4: "Four", 5: "Five"}}).astype(str)
# Out:
#   File "<ipython-input-77-4188e4cb3d0b>", line 5
#     dataset1["Generation"] = dataset1["Generation"].map({1: "One", 2: "Two", 3: "Three", 4: "Four", 5: "Five"}, 6: "Six")}.astype(str)
#                                                                                                                  ^
# SyntaxError: invalid syntax
